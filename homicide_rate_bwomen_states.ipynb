# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
#Carregando nosso DF
os.chdir('/content/drive/MyDrive/Bases de Dados para Indicadores EUROFOUND/Base de Dados')
homicide_rate_bwomen_states = pd.read_csv('taxa-de-homicidios-mulheres-negras.csv', sep = ';')

# %%
homicide_rate_bwomen_states.head()
# Out:
#    cod nome  período  valor
# 0   15   PA     2000   3.76
# 1   50   MS     2000   6.77
# 2   31   MG     2000   2.91
# 3   52   GO     2000   3.65
# 4   32   ES     2000   5.89

# %%
#Selecionando as colunas que precisamos
homicide_rate_bwomen_states = homicide_rate_bwomen_states.drop(['nome'], axis = 1)
homicide_rate_bwomen_states.head()
# Out:
#    cod  período  valor
# 0   15     2000   3.76
# 1   50     2000   6.77
# 2   31     2000   2.91
# 3   52     2000   3.65
# 4   32     2000   5.89

# %%
#Pivotando nosso dataframe
homicide_rate_bwomen_states_T = homicide_rate_bwomen_states.pivot_table(index = 'período', columns = 'cod', values = 'valor')
homicide_rate_bwomen_states_T
# Out:
# cod         11    12    13     14    15    16    17    21    22     23  ...  \
# período                                                                 ...
# 2000      8.06  4.37  3.67   1.34  3.76  2.67  2.44  1.10  0.68   1.96  ...
# 2001     12.21  3.11  5.60   6.22  4.46  5.67  3.30  1.63  2.06   2.19  ...
# 2002      7.58  4.92  3.29   8.62  3.75  4.67  3.58  1.38  1.58   1.77  ...
# 2003      8.72  3.96  3.65   4.92  4.41  6.36  3.77  2.49  2.03   1.41  ...
# 2004      2.70  2.57  2.93   2.30  2.83  6.38  3.04  1.84  1.18   1.58  ...
# 2005      5.94  3.03  3.15   6.86  3.62  5.68  3.27  2.06  2.39   1.62  ...
# 2006      6.32  3.11  2.65   2.13  4.21  4.38  3.64  2.40  2.34   2.29  ...
# 2007      3.78  3.45  3.42   6.87  4.01  3.66  5.27  2.05  1.98   2.95  ...
# 2008      3.93  1.79  4.25   3.44  4.77  5.16  3.36  2.76  2.53   2.55  ...
# 2009      6.35  2.21  4.36   8.25  5.11  4.25  4.59  2.64  1.74   2.60  ...
# ...

# %%
homidicide_rate_bwomen_states_T = homicide_rate_bwomen_states_T.reset_index(inplace = True)
print(homicide_rate_bwomen_states_T)
# Out:
# cod  período     11    12    13     14    15    16    17    21    22  ...  \
# 0       2000   8.06  4.37  3.67   1.34  3.76  2.67  2.44  1.10  0.68  ...
# 1       2001  12.21  3.11  5.60   6.22  4.46  5.67  3.30  1.63  2.06  ...
# 2       2002   7.58  4.92  3.29   8.62  3.75  4.67  3.58  1.38  1.58  ...
# 3       2003   8.72  3.96  3.65   4.92  4.41  6.36  3.77  2.49  2.03  ...
# 4       2004   2.70  2.57  2.93   2.30  2.83  6.38  3.04  1.84  1.18  ...
# 5       2005   5.94  3.03  3.15   6.86  3.62  5.68  3.27  2.06  2.39  ...
# 6       2006   6.32  3.11  2.65   2.13  4.21  4.38  3.64  2.40  2.34  ...
# 7       2007   3.78  3.45  3.42   6.87  4.01  3.66  5.27  2.05  1.98  ...
# 8       2008   3.93  1.79  4.25   3.44  4.77  5.16  3.36  2.76  2.53  ...
# 9       2009   6.35  2.21  4.36   8.25  5.11  4.25  4.59  2.64  1.74  ...
# 10      2010   4.24  4.68  4.39   6.20  6.57  5.60  6.01  3.83  2.25  ...
# 11      2011   5.80  3.86  4.85   6.22  5.08  6.05  7.23  4.13  2.28  ...
# ...

# %%
homicide_rate_bwomen_states_T = homicide_rate_bwomen_states_T.rename(columns = {'período': 'time'})
homicide_rate_bwomen_states_T.head()
# Out:
# cod  time     11    12    13    14    15    16    17    21    22  ...    32  \
# 0    2000   8.06  4.37  3.67  1.34  3.76  2.67  2.44  1.10  0.68  ...  5.89
# 1    2001  12.21  3.11  5.60  6.22  4.46  5.67  3.30  1.63  2.06  ...  6.49
# 2    2002   7.58  4.92  3.29  8.62  3.75  4.67  3.58  1.38  1.58  ...  8.29
# 3    2003   8.72  3.96  3.65  4.92  4.41  6.36  3.77  2.49  2.03  ...  7.39
# 4    2004   2.70  2.57  2.93  2.30  2.83  6.38  3.04  1.84  1.18  ...  7.32
#
# cod    33    35    41    42    43    50    51    52    53
# 0    8.66  7.92  2.23  4.93  3.88  6.77  6.30  3.65  5.60
# 1    9.67  7.71  2.38  3.92  2.96  6.62  7.17  3.96  5.72
# 2    9.12  7.08  3.19  3.43  5.48  7.39  6.72  4.55  5.89
# 3    8.18  7.37  2.78  3.12  3.75  4.89  6.16  4.81  7.21
# 4    7.08  5.33  3.49  2.69  4.66  5.35  7.26  3.89  6.64
#
# [5 rows x 28 columns]

# %%
#Salvando nosso DF
homicide_rate_bwomen_states = homicide_rate_bwomen_states_T
homicide_rate_bwomen_states.to_csv('/content/drive/MyDrive/Bases de Dados para Indicadores EUROFOUND/Bases Finais/homicide_rate_bwomen_states.csv', encoding='UTF-8', index = False)
