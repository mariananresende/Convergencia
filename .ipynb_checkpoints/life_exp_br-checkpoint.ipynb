# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('/content/drive/MyDrive/Bases de Dados para Indicadores EUROFOUND')
life_exp_br = pd.read_csv('ADH_BASE_RADAR_2012-2021.csv')

# %%
life_exp_br.head()
# Out:
#     ANO AGREGACAO  CODIGO NOME   IDHM  IDHM_L  IDHM_E  IDHM_R  I_ESCOLARIDADE  \
# 0  2012    BRASIL     NaN  NaN  0.746   0.825   0.687   0.732           0.606
# 1  2013    BRASIL     NaN  NaN  0.753   0.830   0.698   0.737           0.615
# 2  2014    BRASIL     NaN  NaN  0.762   0.835   0.715   0.741           0.630
# 3  2015    BRASIL     NaN  NaN  0.765   0.840   0.724   0.736           0.642
# 4  2016    BRASIL     NaN  NaN  0.771   0.845   0.740   0.734           0.657
#
#    I_FREQ_PROP  ...        POP6A17       POP11A13       POP15A17  \
# 0        0.731  ...    39,808,859     10,304,212     10,609,288
# 1        0.744  ...    39,055,262      9,986,737     10,521,249
# 2        0.761  ...    38,765,780      9,687,655     10,446,675
# 3        0.769  ...    38,189,476      9,314,133     10,401,307
# 4        0.786  ...    37,694,949      9,288,033     10,375,148
#
#            POP15M       POP18A20       POP18A24          POP18M  \
# ...

# %%
#Selecionando as colunas que precisamos
life_exp_br = life_exp_states_br[['ANO', 'AGREGACAO', 'ESPVIDA']]
life_exp_br.head(15)
# Out:
#      ANO AGREGACAO  ESPVIDA
# 0   2012    BRASIL    74.48
# 1   2013    BRASIL    74.80
# 2   2014    BRASIL    75.11
# 3   2015    BRASIL    75.40
# 4   2016    BRASIL    75.68
# 5   2017    BRASIL    75.96
# 6   2018    BRASIL    76.22
# 7   2019    BRASIL    76.47
# 8   2020    BRASIL    76.21
# 9   2021    BRASIL    74.16
# 10  2012        UF    70.50
# 11  2012        UF    72.47
# 12  2012        UF    70.85
# 13  2012        UF    70.10
# 14  2012        UF    71.23

# %%
#Selecionando as linhas que precisamos
life_exp_br = life_exp_br[life_exp_br["AGREGACAO"].str.contains("BRASIL")]
life_exp_br
# Out:
#     ANO AGREGACAO  ESPVIDA
# 0  2012    BRASIL    74.48
# 1  2013    BRASIL    74.80
# 2  2014    BRASIL    75.11
# 3  2015    BRASIL    75.40
# 4  2016    BRASIL    75.68
# 5  2017    BRASIL    75.96
# 6  2018    BRASIL    76.22
# 7  2019    BRASIL    76.47
# 8  2020    BRASIL    76.21
# 9  2021    BRASIL    74.16

# %%
#Pivotando o dataset para formato Tidy
pivot_life_exp_br = life_exp_br.pivot_table(index='ANO', columns='AGREGACAO', values='ESPVIDA')
pivot_life_exp_br
# Out:
# AGREGACAO  BRASIL
# ANO
# 2012        74.48
# 2013        74.80
# 2014        75.11
# 2015        75.40
# 2016        75.68
# 2017        75.96
# 2018        76.22
# 2019        76.47
# 2020        76.21
# 2021        74.16

# %%
pivot_life_exp_br.reset_index(inplace=True)
pivot_life_exp_br.rename(columns={'index': 'ANO'}, inplace=True)

# %%
nomes_colunas = {"ANO":'time', 'BRASIL':'BR'}
life_exp_br = pivot_life_exp_br.rename(columns=nomes_colunas)
life_exp_br
# Out:
# AGREGACAO  time     BR
# 0          2012  74.48
# 1          2013  74.80
# 2          2014  75.11
# 3          2015  75.40
# 4          2016  75.68
# 5          2017  75.96
# 6          2018  76.22
# 7          2019  76.47
# 8          2020  76.21
# 9          2021  74.16

# %%
life_exp_br.to_csv('/content/drive/MyDrive/Bases de Dados para Indicadores EUROFOUND/life_exp_br.csv',encoding='UTF-8', index=False)
